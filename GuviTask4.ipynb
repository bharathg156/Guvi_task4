# %% [markdown]
# Assessment
# I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems
# import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r'C:\Users\bharath.g\Desktop\files\college_1.csv')
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2=pd.read_csv(r'C:\Users\bharath.g\Desktop\files\college_2.csv').astype({'python':float,'mysql':float})
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K   100.0          0   31.0                       9
# 1                  Chandru     0.0         20    0.0                       0
# 2        Ganesh Ramkumar R    -1.0         55   24.0                       6
# 3          Bodipudi Harini    -1.0          0   35.0                      -1
# 4                VIINU V P    -1.0        100   24.0                      -1
# 5               Poojitha Y     0.0         78   35.0                       0
# 6   Gowtham Chandrasekaran    -1.0          0    0.0                       3
# 7                Gowtham R    -1.0         60    4.0                       6
# 8                 shifak N    58.0          0    0.0                       0
# 9                  Balaji     -1.0        100   20.0                       0
# 10                Rushitha    -1.0         15   62.0                       9
# ...

# %%
df=pd.merge(df1,df2,how='outer')
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# 1.Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
df1 = pd.read_csv(r'C:\Users\bharath.g\Desktop\files\college_1.csv')
df2 = pd.read_csv(r'C:\Users\bharath.g\Desktop\files\college_2.csv')
df_1 = df1.groupby(['Department']).value_counts()
df_2 = df2.groupby(['Department']).value_counts()

# %% [markdown]
# if 10000<codekata score<15000 (Reached_expectations.csv)

# %%
Reached_expectations=df[(df['CodeKata Score']>10000)&(df['CodeKata Score']<15000)]
Reached_expectations.to_csv('Reached_expectations.csv')

# %% [markdown]
# if 7000<codekata score<10000 (Needs_Improvement.csv)

# %%
Needs_Improvement=df[(df['CodeKata Score']>7000)&(df['CodeKata Score']<10000)]
Needs_Improvement.to_csv('Needs_Improvement.csv')

# %% [markdown]
# if codekate score < 7000 (Unsatisfactory.csv)

# %%
Unsatisfactory=df[df['CodeKata Score']<7000]
Unsatisfactory.to_csv('Unsatisfactory.csv')

# %% [markdown]
# Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
prev_geek=df['Previous Geekions'].mean()

# %%
codekata_geek=df['CodeKata Score'].mean()

# %%
print(prev_geek,codekata_geek)
# Out:
# 3842.3529411764707 4051.764705882353

# %% [markdown]
# No of students participated

# %%
df['Name'].nunique()
# Out:
# 119

# %% [markdown]
# Average completion of python course or my_sql or python english or computational thinking

# %%
df['python'].mean(),df['mysql'].mean(),df['python_en'].mean(),df['computational_thinking'].mean()
# Out:
# (54.35294117647059, 23.5, 29.65714285714286, 2.2)

# %% [markdown]
# rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star=df.nlargest(3,'Rising')
rising_star
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %% [markdown]
# Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_stars=df.sort_values(by='Previous Geekions',ascending=False).head(3)

# %%
Shining_stars
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# Department wise codekata performence (pie chart)

# %%
codkata_perf=df.groupby('Department')['CodeKata Score'].sum()
mylabels=['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering ']
plt.pie(codkata_perf,labels=mylabels,autopct='%1.0f%%')
plt.show()

# %% [markdown]
# Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
CS=df[df['Department']=='Computer Science and Engineering']

# %%
CS.sort_values(by='CodeKata Score',ascending=False,inplace=True)
# Out:
# C:\Users\bharath.g\AppData\Local\Temp\ipykernel_20260\3462893013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CS.sort_values(by='CodeKata Score',ascending=False,inplace=True)

# %%
students_name=CS1['Name'].head()

# %%
students_score=CS1['CodeKata Score'].head()

# %%
plt.barh(students_name,students_score)
# Out:
# <BarContainer object of 5 artists>

# %%
E_E=df[df['Department']=='Electronics and Electrical Engineering']
E_E.sort_values(by='CodeKata Score',ascending=False,inplace=True)
students_name=E_E['Name'].head()
students_score=E_E['CodeKata Score'].head()
plt.barh(students_name,students_score)
# Out:
# C:\Users\bharath.g\AppData\Local\Temp\ipykernel_20260\3698476886.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_E.sort_values(by='CodeKata Score',ascending=False,inplace=True)
# <BarContainer object of 5 artists>

# %%
ECE=df[df['Department']=='Electronics and Communication Engineering']
ECE.sort_values(by='CodeKata Score',ascending=False,inplace=True)
students_name=ECE['Name'].head()
students_score=ECE['CodeKata Score'].head()
plt.barh(students_name,students_score)
# Out:
# C:\Users\bharath.g\AppData\Local\Temp\ipykernel_20260\2902793621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ECE.sort_values(by='CodeKata Score',ascending=False,inplace=True)
# <BarContainer object of 5 artists>
